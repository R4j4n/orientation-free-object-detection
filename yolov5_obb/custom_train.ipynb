# %%
# !python3 yolov5-utils/voc2yolo5_obb.py --path small_sample --class-file classes.txt

# %%
# !rm -rf uno_stamp
# !python3 yolov5-utils/data_split.py --datapath small_sample --outpath uno_stamp

# %%
!(cd uno_stamp;ln -s labels labelTxt)

# %%
# %%bash
# cat << EOS > data/uno_stamp.yaml
#
# train: uno_stamp/images/train/    # train images (relative to 'path')
# val: uno_stamp/images/valid/   # val images (relative to 'path')
#
# # Classes
# nc: 2  # number of classes
# names: [
#   'stamp',
#   'uno',
# ]
# EOS

# %%
# !pip install 'protobuf<=3.20.1' --force-reinstall
# Out:
# WARNING: Ignoring invalid distribution -cipy (/home/ml/suruchi/anaconda3/envs/yolo/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/home/ml/suruchi/anaconda3/envs/yolo/lib/python3.9/site-packages)
# ...
#   Using cached protobuf-3.20.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# WARNING: Ignoring invalid distribution -cipy (/home/ml/suruchi/anaconda3/envs/yolo/lib/python3.9/site-packages)
# ...
#   Attempting uninstall: protobuf
#     WARNING: Ignoring invalid distribution -cipy (/home/ml/suruchi/anaconda3/envs/yolo/lib/python3.9/site-packages)
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# WARNING: Ignoring invalid distribution -cipy (/home/ml/suruchi/anaconda3/envs/yolo/lib/python3.9/site-packages)
# ...

# %%
# !python3 train.py --data data/uno_stamp.yaml --cfg models/yolov5m.yaml --batch-size 8 --device 0,1 --patience 500 --epochs 500
# Out:
# train: weights=weights/yolov5n.pt, cfg=models/yolov5m.yaml, data=data/uno_stamp.yaml, hyp=data/hyps/obb/hyp.finetune_dota.yaml, epochs=500, batch_size=8, imgsz=256, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=500, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/hukaixuan19970627/yolov5_obb ✅
# requirements: albumentations==1.3.0 not found and is required by YOLOv5, attempting auto-update...
# WARNING: Ignoring invalid distribution -cipy (/home/ml/suruchi/anaconda3/envs/yolo/lib/python3.9/site-packages)
# ...

# %%
# !python detect.py --weights /home/ml/rajan/YOLO/yolov5_obb/runs/train/exp4/weights/best.pt --source /home/ml/rajan/YOLO/yolov5_obb/uno_stamp/images/valid --device 0 --hide-conf --hide-labels
# Out:
# Namespace(weights=['/home/ml/rajan/YOLO/yolov5_obb/runs/train/exp4/weights/best.pt'], source='/home/ml/rajan/YOLO/yolov5_obb/uno_stamp/images/valid', imgsz=[256], conf_thres=0.1, iou_thres=0.2, max_det=1000, device='0', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project='runs/detect', name='exp', exist_ok=False, line_thickness=2, hide_labels=True, hide_conf=True, half=False, dnn=False)
# ...
